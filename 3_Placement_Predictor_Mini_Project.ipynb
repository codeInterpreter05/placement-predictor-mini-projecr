# %% [markdown]
# <a href="https://colab.research.google.com/github/codeInterpreter05/placement-predictor-mini-project/blob/main/3_Placement_Predictor_Mini_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('/content/modified_placement_data.csv')

# %%
df.head()
# Out:
#    cgpa     iq placement
# 0   6.8  123.0       Yes
# 1   5.4  106.0        No
# 2   7.1  121.0        No
# 3   6.5  132.0       Yes
# 4   4.9  142.0        No

# %%
df.shape
# Out:
# (100, 3)

# %%
# Steps

# 0. Preprocess + EDA + Feature Selection
# 1. Extract input and output cols
# 2. Scale the values
# 3. Train, test and split
# 4. Train the model
# 5. Evaluate the model/model selection
# 6. Deploy the model

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   cgpa       95 non-null     object
#  1   iq         100 non-null    float64
#  2   placement  100 non-null    object
# dtypes: float64(1), object(2)
# memory usage: 2.5+ KB

# %%
import matplotlib.pyplot as plt

df['placement_numeric'] = df['placement'].map({'Yes': 1, 'No': 0})

# Use the numerical values for color mapping
plt.scatter(df['cgpa'], df['iq'], c=df['placement_numeric'])

# %%
X = df.iloc[:, 0:2]
Y = df.iloc[:, -1]

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.1)

# %%
x_train
# Out:
#     cgpa     iq
# 86   7.3   86.0
# 72   6.6  154.0
# 85   4.5  151.0
# 53   7.0  114.0
# 20   7.9  151.0
# ..   ...    ...
# 57   4.4  112.0
# 80   7.2  130.0
# 62   7.3   64.0
# 0    6.8  123.0
# 55   6.6  130.0
#
# [85 rows x 2 columns]

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# %%
from sklearn.linear_model import LogisticRegression

model = LogisticRegression()
model.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
y_pred = model.predict(x_test)

# %%
y_test
# Out:
# 73    0
# 41    1
# 14    0
# 49    0
# 69    1
# 7     0
# 51    1
# 71    0
# 67    1
# 34    1
# Name: placement_numeric, dtype: int64

# %%
from sklearn.metrics import accuracy_score

accuracy_score(y_test, y_pred)
# Out:
# 0.9

# %%
from mlxtend.plotting import plot_decision_regions

plot_decision_regions(x_train, y_train.values, clf=model)
# Out:
# <Axes: >

# %%
import pickle

# %%
pickle.dump(model, open('model.pkl', 'wb'))

# %%
# !git init
# Out:
# hint: Using 'master' as the name for the initial branch. This default branch name
# hint: is subject to change. To configure the initial branch name to use in all
# hint: of your new repositories, which will suppress this warning, call:
# hint:
# hint: 	git config --global init.defaultBranch <name>
# hint:
# hint: Names commonly chosen instead of 'master' are 'main', 'trunk' and
# hint: 'development'. The just-created branch can be renamed via this command:
# hint:
# hint: 	git branch -m <name>
# Initialized empty Git repository in /content/.git/

# %%
# !git branch -M main

# %%
# !git remote add origin https://github.com/codeInterpreter05/placement-predictor-mini-project.git

# %%
# !git pull origin main
# Out:
# remote: Enumerating objects: 6, done.
# remote: Counting objects: 100% (6/6), done.
# remote: Compressing objects: 100% (2/2), done.
# remote: Total 6 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Unpacking objects: 100% (6/6), 1.78 KiB | 913.00 KiB/s, done.
# From https://github.com/codeInterpreter05/placement-predictor-mini-project
#  * branch            main       -> FETCH_HEAD
#  * [new branch]      main       -> origin/main
# error: The following untracked working tree files would be overwritten by merge:
# 	README.md
# Please move or remove them before you merge.
# Aborting

# %%
# !git add .

# %%
# Out:
# fatal: ambiguous argument 'HEAD~1': unknown revision or path not in the working tree.
# Use '--' to separate paths from revisions, like this:
# 'git <command> [<revision>...] -- [<file>...]'

# %%
# !git add .

# %%
# !git config user.name "codeInterpreter05"
# !git config user.email "sarthupadhyay0507@gmail.com"

# !git commit -m "project completed"
# Out:
# [main (root-commit) abc6532] project completed
#  1 file changed, 1 insertion(+)
#  create mode 100644 README.md

# %%
# !git reset --mixed HEAD~1
# Out:
# fatal: ambiguous argument 'HEAD~1': unknown revision or path not in the working tree.
# Use '--' to separate paths from revisions, like this:
# 'git <command> [<revision>...] -- [<file>...]'

# %%
# !git push -u origin main
# Out:
# fatal: could not read Username for 'https://github.com': No such device or address

# %%
# !rm -rf .git
